# %%
import json

# %%
with open('config-example.json', 'r') as json_file:
    json_data = json.load(json_file)

# %%
json_data['slaves'] = {'allo':'bobo', 'allo1':'bobo', 'allo2':'bobo'}

# %%
for key in json_data.keys():
    try: 
        print (key.keys())
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-088a0c91aeb7> in <module>()
#       1 for key in json_data.keys():
# ----> 2     print (key.keys())
#
# AttributeError: 'unicode' object has no attribute 'keys'
